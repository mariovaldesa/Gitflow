# %% [markdown]
# ### Imports

# %%
# Importing required libraries

import pandas as pd
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### Se pasa el json a un dataframe y se filtra para tweets en inglés

# %%
raw_tweets = pd.read_json(r'./farmers-protest-tweets-2021-03-5.json', lines=True)
raw_tweets = raw_tweets[raw_tweets['lang']=='en']
print("Shape: ", raw_tweets.shape)
raw_tweets.head(5)
# Out:
# Shape:  (417511, 21)
#                                                  url  \
# 0  https://twitter.com/ShashiRajbhar6/status/1376...
# 1  https://twitter.com/kaursuk06272818/status/137...
# 2  https://twitter.com/kaursuk06272818/status/137...
# 3  https://twitter.com/SukhdevSingh_/status/13767...
# 4  https://twitter.com/Davidmu66668113/status/137...
#
#                        date  \
# 0 2021-03-30 03:33:46+00:00
# 1 2021-03-30 03:33:23+00:00
# 2 2021-03-30 03:31:00+00:00
# 3 2021-03-30 03:30:45+00:00
# 4 2021-03-30 03:30:30+00:00
#
#                                              content  \
# 0                       Support 👇\n\n#FarmersProtest
# 1  Supporting farmers means supporting our countr...
# 2  Support farmers if you are related to food #St...
# 3  #StopHateAgainstFarmers support #FarmersProtes...
# 4  You hate farmers I hate you, \nif you love the...
#
#                                      renderedContent                   id  \
# ...

# %% [markdown]
# ### Top 10 más retweeted
#
# En la siguiente celda se debería llamar una función para mostrar los 10 tweets más retweeted

# %% [markdown]
# ### Top 10 usuarios que más tweetearon
#
# En la siguiente celda se debería llamar una función para mostrar los 10 usuarios que más tweets hicieron

# %% [markdown]
# ### Top 10 días con más tweets
#
# En la siguiente celda se debería llamar una función para mostrar los 10 días con más tweets

# %% [markdown]
# ### Top 10 hashtags más usados
#
# En la siguiente celda se debería llamar una función para mostrar los 10 hashtags más usados
